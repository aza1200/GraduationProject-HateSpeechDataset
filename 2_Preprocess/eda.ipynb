# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# sns 한국어 패치
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

df = pd.read_excel('./filtered_data.xlsx')

# 클래스 라벨을 설명으로 매핑
class_mapping = {
    0: '일반발언', 1: '성차별', 2: '인종차별',
    3: '종교차별', 4: '연령차별', 5: '정치차별',
    6: '혐오욕설', 7: '출신차별', 8: '외모차별',
    9: '성소수자 차별', 10: '기타혐오'
}

# 'class' 열의 숫자 라벨을 설명으로 변경
df['class'] = df['class'].map(class_mapping)

# 그래프 크기 설정
plt.figure(figsize=(10, 6))

# 빈도수 계산 및 그래프 표시
class_counts = df['class'].value_counts()
class_counts.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Counts')
plt.title('Frequency of Each Class')

# X축 라벨 회전 및 간격 조정
plt.xticks(rotation=45)

# 각 막대에 높이 표시
for index, value in enumerate(class_counts):
    plt.text(index - 0.3, value + 0.5, str(value), verticalalignment='bottom')

plt.show()

# %%
df[df['class']=='일반발언'].sample(10)
# # 각 class 별로 10개씩 출력
# for class_name, group in df.groupby('class'):
#     print(f"Class: {class_name}")
# Out:
#                                         text class
# 92984                왜케 이쁘게 안보노...부러우며지는거다..  일반발언
# 863                   더불어민주당 의문의 침묵 ㅋㅋㅋㅋㅋㅋㅋㅋ  일반발언
# 137294               절대 하면 않됨.한국은 난민수용소가아니다.  일반발언
# 121648                               최고의 걸그룹  일반발언
# 109765       어디아픈사람같네조여정 옛날모습이 더 예쁜데조여정=베이글녀  일반발언
# 78387                       누구지 ? 동네 살찐 누나인가  일반발언
# 107742  유일하게 소처럼 일하지 않은 건... 군대... 소처럼 끌려갔지.  일반발언
# 55341                          "중국조선족이다 OOO"  일반발언
# 94919                 또 김남주머리 유행탈듯 완전 이쁘더라..  일반발언
# 134193                               심각한일이로다  일반발언

# %%
df[df['class']=='성차별'].sample(10)
# Out:
#                                                      text class
# 28733                              여자들 피해엔 민감하고 가해엔 둔감하지.   성차별
# 144456  정작 자신은 페미가 아니라고해도 대부분의 여자들이결국 페미가 정당하지 않게 우겨서 ...   성차별
# 131335        말하는거 보니... 붉은음녀 답네...ㅜㅜ  묘락질하는 이리같은 붉은음녀.!!   성차별
# 96939                            역시 남자는 어려야돼.. 영앤리치앤핸섬 피쓰   성차별
# 23874   머국은 어째서 아직도 냄져나 유충 비율이 이렇게 높은거노? 선택적 출산이 아예 불가...   성차별
# 11482   세상을 망치는 지름길입니다 아이를 낳지 않고 인구가 줄고 대리모라는게 자신의 (남자...   성차별
# 41146                    근데 남자들이 댓글 더많네 저남자가 부러워서 ㅂㄷㅂㄷㅂㄷ?   성차별
# 30853                                    계집들 떡국 끓이러 가라 ㅋㅋ   성차별
# 144171      여자가때려봤자 얼마나아프다고 남자가찌질하게 여자가때렸다고 쳐? 정당화? 육갑들떤다   성차별
# 38881                                   "맘충이 맘충했네..이윽씨.."   성차별
